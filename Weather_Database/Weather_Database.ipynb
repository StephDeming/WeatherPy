# %%
# Import the dependencies.
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
from datetime import datetime
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Perform an API call with the OpenWeatherMap
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d9667b35e4fe648fd876fec76b4374c1

# %%
# 6. Retrieve the following information from the API call:

#Latitude and longitude
#Maximum temperature
#Percent humidity
#Percent cloudiness
#Wind speed
#Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
  
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                           "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 1 | chapais
# Processing Record 3 of Set 1 | yulara
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | shakawe
# Processing Record 7 of Set 1 | aklavik
# Processing Record 8 of Set 1 | xam nua
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | nanakuli
# Processing Record 11 of Set 1 | port-gentil
# Processing Record 12 of Set 1 | peace river
# Processing Record 13 of Set 1 | chengde
# Processing Record 14 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 1 | kavieng
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | hays
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | manzhouli
# Processing Record 26 of Set 1 | havoysund
# Processing Record 27 of Set 1 | canaries
# Processing Record 28 of Set 1 | atar
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | abancay
# Processing Record 31 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | igrim
# Processing Record 34 of Set 1 | karratha
# Processing Record 35 of Set 1 | lavrentiya
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | anadyr
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | livani
# Processing Record 42 of Set 1 | porto novo
# Processing Record 43 of Set 1 | prince rupert
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | yatou
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | buala
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | rondonopolis
# Processing Record 3 of Set 2 | san quintin
# Processing Record 4 of Set 2 | cayenne
# Processing Record 5 of Set 2 | ca mau
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 2 | kruisfontein
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 2 | tupik
# Processing Record 13 of Set 2 | katha
# City not found. Skipping...
# Processing Record 14 of Set 2 | praia
# Processing Record 15 of Set 2 | emerald
# Processing Record 16 of Set 2 | ngama
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 2 | palmer
# Processing Record 21 of Set 2 | tecoanapa
# Processing Record 22 of Set 2 | ibra
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | kachug
# Processing Record 25 of Set 2 | saint anthony
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | avera
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | nizhnyaya tavda
# Processing Record 30 of Set 2 | aripuana
# Processing Record 31 of Set 2 | salalah
# Processing Record 32 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | grindavik
# Processing Record 36 of Set 2 | nanortalik
# Processing Record 37 of Set 2 | wilmington
# Processing Record 38 of Set 2 | portland
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | magadan
# Processing Record 41 of Set 2 | shillong
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | hingatungan
# Processing Record 45 of Set 2 | zalari
# Processing Record 46 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 2 | niono
# Processing Record 50 of Set 2 | trairi
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | itarema
# Processing Record 3 of Set 3 | cidreira
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 3 | coihaique
# Processing Record 7 of Set 3 | saurimo
# Processing Record 8 of Set 3 | codrington
# Processing Record 9 of Set 3 | amahai
# Processing Record 10 of Set 3 | vao
# Processing Record 11 of Set 3 | barabai
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | oranjemund
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | teya
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | darab
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | qaqortoq
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | constitucion
# Processing Record 24 of Set 3 | mastic beach
# Processing Record 25 of Set 3 | panlaitan
# Processing Record 26 of Set 3 | bac lieu
# Processing Record 27 of Set 3 | innisfail
# Processing Record 28 of Set 3 | inhambane
# Processing Record 29 of Set 3 | sabang
# Processing Record 30 of Set 3 | vanimo
# Processing Record 31 of Set 3 | khatanga
# Processing Record 32 of Set 3 | ratnagiri
# Processing Record 33 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 3 | hobart
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | novyy urengoy
# Processing Record 37 of Set 3 | souillac
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | tasiilaq
# Processing Record 40 of Set 3 | moberly
# Processing Record 41 of Set 3 | taoudenni
# Processing Record 42 of Set 3 | nhulunbuy
# Processing Record 43 of Set 3 | cape town
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 3 | ostrovnoy
# Processing Record 47 of Set 3 | moron
# Processing Record 48 of Set 3 | whitehorse
# Processing Record 49 of Set 3 | bestobe
# Processing Record 50 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | ikwiriri
# Processing Record 3 of Set 4 | gravdal
# Processing Record 4 of Set 4 | namatanai
# Processing Record 5 of Set 4 | sitka
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | biscarrosse
# Processing Record 10 of Set 4 | jinchang
# Processing Record 11 of Set 4 | chumikan
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | baiyin
# Processing Record 14 of Set 4 | ambon
# Processing Record 15 of Set 4 | torbay
# Processing Record 16 of Set 4 | athabasca
# Processing Record 17 of Set 4 | qianan
# Processing Record 18 of Set 4 | grand gaube
# Processing Record 19 of Set 4 | pevek
# Processing Record 20 of Set 4 | kastamonu
# Processing Record 21 of Set 4 | saint-pierre
# Processing Record 22 of Set 4 | tautira
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | leh
# Processing Record 25 of Set 4 | grande-riviere
# City not found. Skipping...
# Processing Record 26 of Set 4 | srednekolymsk
# Processing Record 27 of Set 4 | riyadh
# Processing Record 28 of Set 4 | padang
# Processing Record 29 of Set 4 | vigrestad
# Processing Record 30 of Set 4 | port lincoln
# Processing Record 31 of Set 4 | inuvik
# Processing Record 32 of Set 4 | otradnoye
# Processing Record 33 of Set 4 | vila franca do campo
# Processing Record 34 of Set 4 | kaseda
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | dingle
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | carutapera
# Processing Record 39 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | sao jose de ribamar
# Processing Record 41 of Set 4 | fez
# Processing Record 42 of Set 4 | acarau
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | dungarpur
# Processing Record 45 of Set 4 | koslan
# Processing Record 46 of Set 4 | zastron
# Processing Record 47 of Set 4 | pozo colorado
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | maroantsetra
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | la macarena
# Processing Record 2 of Set 5 | miri
# Processing Record 3 of Set 5 | lenger
# Processing Record 4 of Set 5 | vicuna
# Processing Record 5 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 5 | tual
# Processing Record 7 of Set 5 | labuhan
# Processing Record 8 of Set 5 | muros
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | shirokiy
# Processing Record 11 of Set 5 | arlit
# Processing Record 12 of Set 5 | nabire
# Processing Record 13 of Set 5 | severo-kurilsk
# Processing Record 14 of Set 5 | coahuayana
# Processing Record 15 of Set 5 | nara
# Processing Record 16 of Set 5 | sioux lookout
# Processing Record 17 of Set 5 | naryan-mar
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | san rafael del sur
# Processing Record 20 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 5 | bandarbeyla
# Processing Record 22 of Set 5 | port elizabeth
# Processing Record 23 of Set 5 | kavaratti
# Processing Record 24 of Set 5 | dalbandin
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | solnechnyy
# Processing Record 27 of Set 5 | yamasaki
# Processing Record 28 of Set 5 | ancud
# Processing Record 29 of Set 5 | kifri
# Processing Record 30 of Set 5 | terdal
# Processing Record 31 of Set 5 | cherskiy
# Processing Record 32 of Set 5 | inta
# Processing Record 33 of Set 5 | bethel
# Processing Record 34 of Set 5 | ouahigouya
# Processing Record 35 of Set 5 | marsa matruh
# Processing Record 36 of Set 5 | peraiyur
# Processing Record 37 of Set 5 | castro
# Processing Record 38 of Set 5 | port moresby
# Processing Record 39 of Set 5 | sambhar
# Processing Record 40 of Set 5 | kungurtug
# Processing Record 41 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 42 of Set 5 | arnedo
# Processing Record 43 of Set 5 | fortuna foothills
# Processing Record 44 of Set 5 | nantucket
# Processing Record 45 of Set 5 | kamenka
# Processing Record 46 of Set 5 | duz
# City not found. Skipping...
# Processing Record 47 of Set 5 | saint george
# Processing Record 48 of Set 5 | cairns
# Processing Record 49 of Set 5 | matara
# Processing Record 50 of Set 5 | jiaocheng
# Processing Record 1 of Set 6 | meulaboh
# Processing Record 2 of Set 6 | puerto ayora
# Processing Record 3 of Set 6 | nikolayevsk-na-amure
# Processing Record 4 of Set 6 | amuntai
# Processing Record 5 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 6 | shimoda
# Processing Record 7 of Set 6 | nizhneudinsk
# Processing Record 8 of Set 6 | litovko
# Processing Record 9 of Set 6 | nishihara
# Processing Record 10 of Set 6 | marathon
# Processing Record 11 of Set 6 | careiro da varzea
# Processing Record 12 of Set 6 | herat
# Processing Record 13 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 6 | oistins
# Processing Record 15 of Set 6 | mizdah
# Processing Record 16 of Set 6 | onega
# Processing Record 17 of Set 6 | sinegorskiy
# Processing Record 18 of Set 6 | nouadhibou
# Processing Record 19 of Set 6 | tura
# Processing Record 20 of Set 6 | sangar
# Processing Record 21 of Set 6 | beringovskiy
# Processing Record 22 of Set 6 | san policarpo
# Processing Record 23 of Set 6 | antofagasta
# Processing Record 24 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 6 | pestravka
# Processing Record 26 of Set 6 | kahului
# Processing Record 27 of Set 6 | popondetta
# Processing Record 28 of Set 6 | kandrian
# Processing Record 29 of Set 6 | galesong
# Processing Record 30 of Set 6 | tlacotepec
# Processing Record 31 of Set 6 | solnechnogorsk
# Processing Record 32 of Set 6 | hida
# Processing Record 33 of Set 6 | nome
# Processing Record 34 of Set 6 | tonj
# Processing Record 35 of Set 6 | bure
# Processing Record 36 of Set 6 | narsaq
# Processing Record 37 of Set 6 | sisimiut
# Processing Record 38 of Set 6 | namibe
# Processing Record 39 of Set 6 | kralendijk
# Processing Record 40 of Set 6 | rio grande
# Processing Record 41 of Set 6 | naklo nad notecia
# Processing Record 42 of Set 6 | ilulissat
# Processing Record 43 of Set 6 | puerto escondido
# Processing Record 44 of Set 6 | mackay
# Processing Record 45 of Set 6 | takaka
# Processing Record 46 of Set 6 | gamboma
# Processing Record 47 of Set 6 | clyde river
# Processing Record 48 of Set 6 | iki-burul
# Processing Record 49 of Set 6 | lubbock
# Processing Record 50 of Set 6 | kuytun
# Processing Record 1 of Set 7 | campeche
# Processing Record 2 of Set 7 | lubao
# Processing Record 3 of Set 7 | santa vitoria do palmar
# Processing Record 4 of Set 7 | broken hill
# Processing Record 5 of Set 7 | raga
# Processing Record 6 of Set 7 | kilemary
# Processing Record 7 of Set 7 | chato
# Processing Record 8 of Set 7 | keti bandar
# Processing Record 9 of Set 7 | najran
# Processing Record 10 of Set 7 | cabreuva
# Processing Record 11 of Set 7 | charters towers
# Processing Record 12 of Set 7 | daru
# Processing Record 13 of Set 7 | aktau
# Processing Record 14 of Set 7 | cayeli
# Processing Record 15 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 7 | hohhot
# Processing Record 17 of Set 7 | taitung
# Processing Record 18 of Set 7 | dunedin
# Processing Record 19 of Set 7 | batemans bay
# Processing Record 20 of Set 7 | at-bashi
# Processing Record 21 of Set 7 | fortuna
# Processing Record 22 of Set 7 | flinders
# Processing Record 23 of Set 7 | nan
# Processing Record 24 of Set 7 | bodaybo
# Processing Record 25 of Set 7 | saint-georges
# Processing Record 26 of Set 7 | camacha
# Processing Record 27 of Set 7 | mamit
# Processing Record 28 of Set 7 | lovozero
# Processing Record 29 of Set 7 | adrar
# Processing Record 30 of Set 7 | the valley
# Processing Record 31 of Set 7 | hasaki
# Processing Record 32 of Set 7 | rawson
# Processing Record 33 of Set 7 | half moon bay
# Processing Record 34 of Set 7 | otavi
# Processing Record 35 of Set 7 | bitung
# Processing Record 36 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 7 | kalmunai
# Processing Record 38 of Set 7 | road town
# Processing Record 39 of Set 7 | aksarka
# Processing Record 40 of Set 7 | verkhnevilyuysk
# Processing Record 41 of Set 7 | shingu
# Processing Record 42 of Set 7 | talnakh
# Processing Record 43 of Set 7 | marrakesh
# Processing Record 44 of Set 7 | kilindoni
# Processing Record 45 of Set 7 | san patricio
# Processing Record 46 of Set 7 | chicama
# Processing Record 47 of Set 7 | ordu
# Processing Record 48 of Set 7 | silifke
# Processing Record 49 of Set 7 | kondinskoye
# Processing Record 50 of Set 7 | sept-iles
# Processing Record 1 of Set 8 | touros
# Processing Record 2 of Set 8 | camocim
# Processing Record 3 of Set 8 | urumqi
# Processing Record 4 of Set 8 | kiama
# Processing Record 5 of Set 8 | bahia honda
# Processing Record 6 of Set 8 | victoria
# Processing Record 7 of Set 8 | yuanping
# Processing Record 8 of Set 8 | mehamn
# Processing Record 9 of Set 8 | ust-tsilma
# Processing Record 10 of Set 8 | ukiah
# Processing Record 11 of Set 8 | bimbo
# Processing Record 12 of Set 8 | mungwi
# Processing Record 13 of Set 8 | menongue
# Processing Record 14 of Set 8 | provideniya
# Processing Record 15 of Set 8 | sinnamary
# Processing Record 16 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 8 | koungou
# Processing Record 18 of Set 8 | fredericksburg
# Processing Record 19 of Set 8 | san juan
# Processing Record 20 of Set 8 | ishigaki
# Processing Record 21 of Set 8 | puerto madryn
# Processing Record 22 of Set 8 | sao filipe
# Processing Record 23 of Set 8 | bhanpuri
# Processing Record 24 of Set 8 | shimanovsk
# Processing Record 25 of Set 8 | shahreza
# Processing Record 26 of Set 8 | nova zagora
# Processing Record 27 of Set 8 | winsum
# Processing Record 28 of Set 8 | rincon
# Processing Record 29 of Set 8 | jijiang
# Processing Record 30 of Set 8 | ribeira grande
# Processing Record 31 of Set 8 | santiago del estero
# Processing Record 32 of Set 8 | axim
# Processing Record 33 of Set 8 | thompson
# Processing Record 34 of Set 8 | labrea
# Processing Record 35 of Set 8 | valkeala
# Processing Record 36 of Set 8 | sao joao da barra
# Processing Record 37 of Set 8 | bismarck
# Processing Record 38 of Set 8 | azar shahr
# City not found. Skipping...
# Processing Record 39 of Set 8 | rocha
# Processing Record 40 of Set 8 | lorengau
# Processing Record 41 of Set 8 | sol-iletsk
# Processing Record 42 of Set 8 | baykit
# Processing Record 43 of Set 8 | pitimbu
# Processing Record 44 of Set 8 | sungaipenuh
# Processing Record 45 of Set 8 | hunchun
# Processing Record 46 of Set 8 | sabha
# Processing Record 47 of Set 8 | mali
# Processing Record 48 of Set 8 | santa maria
# Processing Record 49 of Set 8 | puerto ayacucho
# Processing Record 50 of Set 8 | roald
# Processing Record 1 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 9 | nouakchott
# Processing Record 3 of Set 9 | phuket
# Processing Record 4 of Set 9 | mazagao
# Processing Record 5 of Set 9 | eyrarbakki
# Processing Record 6 of Set 9 | ivanivka
# Processing Record 7 of Set 9 | ust-kulom
# Processing Record 8 of Set 9 | uniao
# Processing Record 9 of Set 9 | beian
# Processing Record 10 of Set 9 | ocos
# Processing Record 11 of Set 9 | aykhal
# Processing Record 12 of Set 9 | olafsvik
# Processing Record 13 of Set 9 | natal
# Processing Record 14 of Set 9 | minden
# Processing Record 15 of Set 9 | bukan
# Processing Record 16 of Set 9 | sal rei
# Processing Record 17 of Set 9 | timra
# Processing Record 18 of Set 9 | vestmannaeyjar
# Processing Record 19 of Set 9 | balykshi
# Processing Record 20 of Set 9 | kawalu
# Processing Record 21 of Set 9 | tuatapere
# Processing Record 22 of Set 9 | gambiran
# Processing Record 23 of Set 9 | lodja
# Processing Record 24 of Set 9 | manokwari
# Processing Record 25 of Set 9 | vostok
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | tokur
# Processing Record 28 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 9 | epinal
# Processing Record 30 of Set 9 | nuevo progreso
# Processing Record 31 of Set 9 | trincomalee
# Processing Record 32 of Set 9 | soyo
# Processing Record 33 of Set 9 | bereda
# Processing Record 34 of Set 9 | auchi
# Processing Record 35 of Set 9 | tukan
# Processing Record 36 of Set 9 | morehead
# Processing Record 37 of Set 9 | virginia beach
# Processing Record 38 of Set 9 | tigzirt
# Processing Record 39 of Set 9 | margate
# Processing Record 40 of Set 9 | ulaangom
# Processing Record 41 of Set 9 | turayf
# Processing Record 42 of Set 9 | springdale
# Processing Record 43 of Set 9 | isangel
# Processing Record 44 of Set 9 | helong
# Processing Record 45 of Set 9 | bonavista
# Processing Record 46 of Set 9 | mabaruma
# Processing Record 47 of Set 9 | nizwa
# Processing Record 48 of Set 9 | tabou
# Processing Record 49 of Set 9 | fereydunshahr
# Processing Record 50 of Set 9 | kismayo
# Processing Record 1 of Set 10 | hofn
# Processing Record 2 of Set 10 | peniche
# Processing Record 3 of Set 10 | shiozawa
# Processing Record 4 of Set 10 | praya
# Processing Record 5 of Set 10 | egvekinot
# Processing Record 6 of Set 10 | krasnozatonskiy
# Processing Record 7 of Set 10 | westport
# Processing Record 8 of Set 10 | sambava
# Processing Record 9 of Set 10 | pangnirtung
# Processing Record 10 of Set 10 | kudahuvadhoo
# Processing Record 11 of Set 10 | imeni poliny osipenko
# Processing Record 12 of Set 10 | nuuk
# Processing Record 13 of Set 10 | omboue
# Processing Record 14 of Set 10 | huesca
# Processing Record 15 of Set 10 | ahipara
# Processing Record 16 of Set 10 | forio
# Processing Record 17 of Set 10 | bushehr
# Processing Record 18 of Set 10 | bonfim
# Processing Record 19 of Set 10 | todi
# Processing Record 20 of Set 10 | guerrero negro
# Processing Record 21 of Set 10 | sindor
# Processing Record 22 of Set 10 | turkistan
# Processing Record 23 of Set 10 | fukue
# Processing Record 24 of Set 10 | rusera
# Processing Record 25 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 10 | kashi
# Processing Record 27 of Set 10 | sampit
# Processing Record 28 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 29 of Set 10 | bellavista
# Processing Record 30 of Set 10 | benxi
# Processing Record 31 of Set 10 | iquique
# Processing Record 32 of Set 10 | lakshmipur
# Processing Record 33 of Set 10 | auki
# Processing Record 34 of Set 10 | palmerston
# Processing Record 35 of Set 10 | lagos
# Processing Record 36 of Set 10 | kashan
# Processing Record 37 of Set 10 | boa vista
# Processing Record 38 of Set 10 | vardo
# Processing Record 39 of Set 10 | opuwo
# Processing Record 40 of Set 10 | wanning
# Processing Record 41 of Set 10 | wamba
# Processing Record 42 of Set 10 | pinega
# Processing Record 43 of Set 10 | maniitsoq
# Processing Record 44 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 10 | mosquera
# Processing Record 46 of Set 10 | lugovoy
# Processing Record 47 of Set 10 | lac du bonnet
# Processing Record 48 of Set 10 | bathsheba
# Processing Record 49 of Set 10 | awash
# Processing Record 50 of Set 10 | waingapu
# Processing Record 1 of Set 11 | arman
# Processing Record 2 of Set 11 | de-kastri
# Processing Record 3 of Set 11 | sakakah
# Processing Record 4 of Set 11 | laguna
# Processing Record 5 of Set 11 | ondangwa
# Processing Record 6 of Set 11 | zhenlai
# Processing Record 7 of Set 11 | sechura
# Processing Record 8 of Set 11 | poum
# Processing Record 9 of Set 11 | verkhoyansk
# Processing Record 10 of Set 11 | antalaha
# Processing Record 11 of Set 11 | havelock
# Processing Record 12 of Set 11 | namioka
# Processing Record 13 of Set 11 | hope
# Processing Record 14 of Set 11 | kabinda
# Processing Record 15 of Set 11 | buncrana
# Processing Record 16 of Set 11 | wattegama
# Processing Record 17 of Set 11 | khovu-aksy
# Processing Record 18 of Set 11 | yar-sale
# Processing Record 19 of Set 11 | byron bay
# Processing Record 20 of Set 11 | grand-santi
# Processing Record 21 of Set 11 | elko
# Processing Record 22 of Set 11 | iqaluit
# Processing Record 23 of Set 11 | rongcheng
# Processing Record 24 of Set 11 | inirida
# Processing Record 25 of Set 11 | oron
# Processing Record 26 of Set 11 | anchorage
# Processing Record 27 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 28 of Set 11 | dubbo
# Processing Record 29 of Set 11 | sarangani
# Processing Record 30 of Set 11 | rabo de peixe
# Processing Record 31 of Set 11 | malibu
# Processing Record 32 of Set 11 | barcelos
# Processing Record 33 of Set 11 | luang prabang
# Processing Record 34 of Set 11 | mitsamiouli
# Processing Record 35 of Set 11 | zarubino
# Processing Record 36 of Set 11 | palauig
# Processing Record 37 of Set 11 | tabas
# Processing Record 38 of Set 11 | arrifes
# Processing Record 39 of Set 11 | voghera
# Processing Record 40 of Set 11 | zaysan
# Processing Record 41 of Set 11 | itacoatiara
# Processing Record 42 of Set 11 | shache
# Processing Record 43 of Set 11 | linxia
# Processing Record 44 of Set 11 | alofi
# Processing Record 45 of Set 11 | hovd
# Processing Record 46 of Set 11 | kolondieba
# Processing Record 47 of Set 11 | koutsouras
# Processing Record 48 of Set 11 | russell
# Processing Record 49 of Set 11 | dhidhdhoo
# Processing Record 50 of Set 11 | chkalovskoye
# Processing Record 1 of Set 12 | prainha
# Processing Record 2 of Set 12 | barranca de upia
# Processing Record 3 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 12 | hobyo
# Processing Record 5 of Set 12 | rio cuarto
# Processing Record 6 of Set 12 | vaitape
# Processing Record 7 of Set 12 | tan an
# Processing Record 8 of Set 12 | huilong
# Processing Record 9 of Set 12 | dawei
# Processing Record 10 of Set 12 | kroya
# Processing Record 11 of Set 12 | bengkulu
# Processing Record 12 of Set 12 | banda aceh
# Processing Record 13 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 12 | sistranda
# Processing Record 15 of Set 12 | mukhen
# Processing Record 16 of Set 12 | port maria
# Processing Record 17 of Set 12 | katherine
# Processing Record 18 of Set 12 | shakhtinsk
# Processing Record 19 of Set 12 | tondano
# Processing Record 20 of Set 12 | nelson bay
# Processing Record 21 of Set 12 | sao gabriel da cachoeira
# Processing Record 22 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 23 of Set 12 | fairbanks
# Processing Record 24 of Set 12 | padre bernardo
# Processing Record 25 of Set 12 | bama
# Processing Record 26 of Set 12 | mankono
# Processing Record 27 of Set 12 | karwar
# Processing Record 28 of Set 12 | samarai
# Processing Record 29 of Set 12 | mangan
# Processing Record 30 of Set 12 | namtsy
# Processing Record 31 of Set 12 | acin
# City not found. Skipping...
# Processing Record 32 of Set 12 | san rafael
# Processing Record 33 of Set 12 | concarneau
# Processing Record 34 of Set 12 | storsteinnes
# Processing Record 35 of Set 12 | vidim
# Processing Record 36 of Set 12 | buta
# Processing Record 37 of Set 12 | eydhafushi
# Processing Record 38 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 12 | bouza
# Processing Record 40 of Set 12 | anzio
# Processing Record 41 of Set 12 | kupang
# Processing Record 42 of Set 12 | sao jose da coroa grande
# Processing Record 43 of Set 12 | takoradi
# Processing Record 44 of Set 12 | leshukonskoye
# Processing Record 45 of Set 12 | bilma
# Processing Record 46 of Set 12 | akalkot
# Processing Record 47 of Set 12 | revda
# Processing Record 48 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 12 | sovetskiy
# Processing Record 50 of Set 12 | bagotville
# Processing Record 1 of Set 13 | kiruna
# Processing Record 2 of Set 13 | taksimo
# Processing Record 3 of Set 13 | berlevag
# Processing Record 4 of Set 13 | bulungu
# Processing Record 5 of Set 13 | cabedelo
# Processing Record 6 of Set 13 | viedma
# Processing Record 7 of Set 13 | rettikhovka
# Processing Record 8 of Set 13 | kangaatsiaq
# Processing Record 9 of Set 13 | oudtshoorn
# Processing Record 10 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 13 | tilichiki
# Processing Record 12 of Set 13 | nago
# Processing Record 13 of Set 13 | izhma
# Processing Record 14 of Set 13 | srandakan
# Processing Record 15 of Set 13 | tigre
# Processing Record 16 of Set 13 | talas
# Processing Record 17 of Set 13 | soderhamn
# Processing Record 18 of Set 13 | iskateley
# Processing Record 19 of Set 13 | sandnessjoen
# Processing Record 20 of Set 13 | kununurra
# Processing Record 21 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 22 of Set 13 | baturaja
# Processing Record 23 of Set 13 | verkhniye tatyshly
# Processing Record 24 of Set 13 | kartaly
# Processing Record 25 of Set 13 | lasa
# Processing Record 26 of Set 13 | kingman
# Processing Record 27 of Set 13 | krasnogorsk
# Processing Record 28 of Set 13 | bowen
# Processing Record 29 of Set 13 | matay
# Processing Record 30 of Set 13 | port macquarie
# Processing Record 31 of Set 13 | silivainiotika
# City not found. Skipping...
# Processing Record 32 of Set 13 | eenhana
# Processing Record 33 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 13 | port hedland
# Processing Record 35 of Set 13 | zyryanka
# Processing Record 36 of Set 13 | yumen
# Processing Record 37 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 38 of Set 13 | voyvozh
# Processing Record 39 of Set 13 | salta
# Processing Record 40 of Set 13 | sola
# Processing Record 41 of Set 13 | lazaro cardenas
# Processing Record 42 of Set 13 | polohy
# Processing Record 43 of Set 13 | kasempa
# Processing Record 44 of Set 13 | san carlos de bariloche
# Processing Record 45 of Set 13 | bubaque
# Processing Record 46 of Set 13 | verkh-suetka
# Processing Record 47 of Set 13 | santa marta
# Processing Record 48 of Set 13 | hambantota
# Processing Record 49 of Set 13 | birao
# Processing Record 50 of Set 13 | ponta delgada
# Processing Record 1 of Set 14 | port hardy
# Processing Record 2 of Set 14 | beni
# Processing Record 3 of Set 14 | krasne
# Processing Record 4 of Set 14 | jaciara
# Processing Record 5 of Set 14 | bartica
# Processing Record 6 of Set 14 | pinawa
# Processing Record 7 of Set 14 | gwadar
# Processing Record 8 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 14 | udachnyy
# Processing Record 10 of Set 14 | buchanan
# Processing Record 11 of Set 14 | excelsior springs
# Processing Record 12 of Set 14 | paralimni
# Processing Record 13 of Set 14 | qrendi
# Processing Record 14 of Set 14 | magdagachi
# Processing Record 15 of Set 14 | yambio
# Processing Record 16 of Set 14 | modugno
# Processing Record 17 of Set 14 | sibolga
# Processing Record 18 of Set 14 | charlottetown
# Processing Record 19 of Set 14 | tarragona
# Processing Record 20 of Set 14 | victor harbor
# Processing Record 21 of Set 14 | bhimunipatnam
# Processing Record 22 of Set 14 | teknaf
# Processing Record 23 of Set 14 | ucluelet
# Processing Record 24 of Set 14 | deputatskiy
# Processing Record 25 of Set 14 | chabahar
# Processing Record 26 of Set 14 | diego de almagro
# Processing Record 27 of Set 14 | mayna
# Processing Record 28 of Set 14 | havre-saint-pierre
# Processing Record 29 of Set 14 | arrecife
# Processing Record 30 of Set 14 | bairiki
# Processing Record 31 of Set 14 | husum
# Processing Record 32 of Set 14 | ampanihy
# Processing Record 33 of Set 14 | porbandar
# Processing Record 34 of Set 14 | beloha
# Processing Record 35 of Set 14 | roma
# Processing Record 36 of Set 14 | tombouctou
# Processing Record 37 of Set 14 | rafai
# Processing Record 38 of Set 14 | sarahan
# Processing Record 39 of Set 14 | faya
# Processing Record 40 of Set 14 | san luis
# Processing Record 41 of Set 14 | kirakira
# Processing Record 42 of Set 14 | espanola
# Processing Record 43 of Set 14 | russellville
# Processing Record 44 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 14 | qorveh
# Processing Record 46 of Set 14 | mahina
# Processing Record 47 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 48 of Set 14 | tortoli
# Processing Record 49 of Set 14 | saint-joseph
# Processing Record 50 of Set 14 | altay
# Processing Record 1 of Set 15 | zarya
# Processing Record 2 of Set 15 | miguel auza
# Processing Record 3 of Set 15 | hojo
# Processing Record 4 of Set 15 | bridlington
# Processing Record 5 of Set 15 | qasigiannguit
# Processing Record 6 of Set 15 | husavik
# Processing Record 7 of Set 15 | zaragoza
# Processing Record 8 of Set 15 | yamethin
# Processing Record 9 of Set 15 | bara
# Processing Record 10 of Set 15 | sorong
# Processing Record 11 of Set 15 | praia da vitoria
# Processing Record 12 of Set 15 | port blair
# Processing Record 13 of Set 15 | yeppoon
# Processing Record 14 of Set 15 | kanodar
# Processing Record 15 of Set 15 | esna
# Processing Record 16 of Set 15 | morden
# Processing Record 17 of Set 15 | teapa
# Processing Record 18 of Set 15 | provost
# Processing Record 19 of Set 15 | achutupo
# Processing Record 20 of Set 15 | akyab
# Processing Record 21 of Set 15 | pisco
# Processing Record 22 of Set 15 | te anau
# Processing Record 23 of Set 15 | paamiut
# Processing Record 24 of Set 15 | chiusi
# Processing Record 25 of Set 15 | westerland
# Processing Record 26 of Set 15 | tessalit
# Processing Record 27 of Set 15 | turukhansk
# Processing Record 28 of Set 15 | floro
# Processing Record 29 of Set 15 | killybegs
# Processing Record 30 of Set 15 | college
# Processing Record 31 of Set 15 | kattivakkam
# Processing Record 32 of Set 15 | puri
# Processing Record 33 of Set 15 | fomboni
# Processing Record 34 of Set 15 | urucara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add data to new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Chapais  49.7834  -74.8492     38.98        70         100
# 1         Yulara -25.2406  130.9889     84.04        37          34
# 2    East London -33.0153   27.9116     66.90        85          94
# 3  Mar Del Plata -38.0023  -57.5575     62.87        69           0
# 4        Shakawe -18.3667   21.8500     71.87        69          72
# 5        Aklavik  68.2191 -135.0107     27.43        86          90
# 6        Xam Nua  20.4197  104.0439     57.67        99          95
# 7       Hermanus -34.4187   19.2345     66.90        82         100
# 8       Nanakuli  21.3906 -158.1547     86.04        51          20
# 9    Port-Gentil  -0.7193    8.7815     76.96        94          90
#
#    Wind Speed Country                 Date Current Description
# 0        6.38      CA  2021-10-26 23:27:31     overcast clouds
# 1       13.80      AU  2021-10-26 23:27:32    scattered clouds
# 2       20.42      ZA  2021-10-26 23:27:32          light rain
# 3        4.00      AR  2021-10-26 23:27:33           clear sky
# 4        5.19      BW  2021-10-26 23:27:33       broken clouds
# 5        0.00      CA  2021-10-26 23:27:34          light snow
# 6        1.97      LA  2021-10-26 23:27:34     overcast clouds
# 7       16.64      ZA  2021-10-26 23:27:35     overcast clouds
# 8       12.66      US  2021-10-26 23:27:35          few clouds
# 9        9.22      GA  2021-10-26 23:27:35     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
